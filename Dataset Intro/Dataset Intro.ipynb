# %%
from scipy.io import loadmat
image = loadmat('12_comboBI_pLGE_05_image.mat')
label = loadmat('12_comboBI_pLGE_05_image_label.mat')

# %%
for x in image.keys():
    print(x)
print('-------------------')
for x in label.keys():
    print(x)
# Out:
# __header__
# __version__
# __globals__
# pLGE
# tmp_vol_im
# -------------------
# __header__
# __version__
# __globals__
# pLGE
# tmp_vol_im

# %%
image['tmp_vol_im'].shape, label['tmp_vol_im'].shape
# Out:
# ((160, 160, 3, 20), (160, 160, 1, 20))

# %%
plt.imshow(label['tmp_vol_im'][:, :, 0, 9], cmap = 'gray')

# %%
import matplotlib.pyplot as plt
plt.imshow(image['tmp_vol_im'][:, :, 0, 9], cmap = 'gray')

# %%
import matplotlib.pyplot as plt
plt.imshow(image['tmp_vol_im'][:, :, 2, 9], cmap = 'gray')

# %%
import matplotlib.pyplot as plt
plt.imshow(image['tmp_vol_im'][:, :, 1, 9], cmap = 'gray')

# %% [markdown]
# LGE
# - pixel size = 1.0–1.25 × 1.0–1.25 mm2
# - number of slices = 7-24
# - slice thickness = 8–10 mm
#
# Cine
# - pixel size = 0.97–1.25 × 1.0–1.25 mm2
# - slice thickness = 5–10 mm.
#
# Both (Pre-processing)
# - spatial resolution = 1.2 mm
# - images cropped to 160 × 160 matrix

# %% [markdown]
# Paper Link:
# https://pubmed.ncbi.nlm.nih.gov/33599043/
